# %%
import PIL
from PIL import Image
import numpy as np

# %%
img = Image.open("Desktop/test_image.jpg")
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
img.show()

# %%
print(img.format)
img1 = np.asarray(img)
print(type(img1))
# Out:
# JPEG
# <class 'numpy.ndarray'>

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread("Desktop/test_image.jpg")  # import the image using matplotlib will convert the image into numpy array

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (155, 325, 3)

# %%
plt.imshow(img)
plt.colorbar()

# %%
from skimage import io

# %%
image = io.imread("Desktop/test_image.jpg")  # using skimage to access the image converts the image into numpy array
print(type(image))
io.imshow(image)
# Out:
# <class 'numpy.ndarray'>
