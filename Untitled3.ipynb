# %%
import pandas as pd

# %%
df = pd.read_csv("Desktop/playground-series-s4e10/train.csv")
df
# Out:
#           id  person_age  person_income person_home_ownership  \
# 0          0          37          35000                  RENT
# 1          1          22          56000                   OWN
# 2          2          29          28800                   OWN
# 3          3          30          70000                  RENT
# 4          4          22          60000                  RENT
# ...      ...         ...            ...                   ...
# 58640  58640          34         120000              MORTGAGE
# 58641  58641          28          28800                  RENT
# 58642  58642          23          44000                  RENT
# 58643  58643          22          30000                  RENT
# 58644  58644          31          75000              MORTGAGE
#
#        person_emp_length loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0                    0.0   EDUCATION          B       6000          11.49
# ...

# %%
df['person_home_ownership'].unique()
df['loan_grade'].unique()
df['loan_intent'].unique()
# Out:
# array(['EDUCATION', 'MEDICAL', 'PERSONAL', 'VENTURE', 'DEBTCONSOLIDATION',
#        'HOMEIMPROVEMENT'], dtype=object)

# %%
X = df.drop(columns = ['id', 'loan_status'])
y = df['loan_status']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories = [['OTHER', 'RENT', 'MORTGAGE', 'OWN'], ['G', 'F', 'E', 'D', 'C', 'B', 'A'],['PERSONAL', 'VENTURE', 'DEBTCONSOLIDATION', 'HOMEIMPROVEMENT', 'MEDICAL', 'EDUCATION']])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 oe.fit(X_train)
#
# File /opt/anaconda3/envs/tf_env/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:1294, in OrdinalEncoder.fit(self, X, y)
#    1287     raise TypeError(
#    1288         "unknown_value should only be set when "
#    1289         "handle_unknown is 'use_encoded_value', "
#    1290         f"got {self.unknown_value}."
#    1291     )
#    1293 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1294 self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#    1296 if self.handle_unknown == "use_encoded_value":
#    1297     for feature_cats in self.categories_:
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, y_train, X_test, y_test = train_test_split(X,y, test_size = 0.2, random_state = 2)
